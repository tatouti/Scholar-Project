# %%
#!pip install selenium
#!pip install lxml
#!pip install beautifulsoup4
#!pip install webdriver-manager
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re 
import requests

import time
from datetime import datetime

# %%
cinemas = {}
cinemas['La Defense'] = "https://www.ugc.fr/cinema.html?id=20"
cinemas['Les Halles'] = "https://www.ugc.fr/cinema.html?id=10"
cinemas['Montparnasse'] = "https://www.ugc.fr/cinema.html?id=14"

listeType =[]
listeCinemas =[]
listeTitres =[]
listeJour =[]
listeHdebut = []
listeHfin = []
listeDuree = []
listeLangue = []
listeCatégorie = []
listeDSortie = []
listeRealisateurs = []
listeActeurs =[]
listeSynopsis = []
listeAvertissement =[]
listeNumSemaines = []
listeTag =[]

def avantPrem():
    Type = "Avant-Premières"
    Titres ="AP"
    Jour ="AP"
    Hdebut = "AP"
    Hfin = "AP"
    Duree = "AP"
    Langue = "AP"
    Catégorie = "AP"
    DSortie = "AP"
    Realisateurs = "AP"
    Acteurs ="AP"
    Synopsis = "AP"
    Avertissement = "RAS"
    NumSemaines = "0"
    Tag = "AP"
    
    return Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

def prev():    
    Type = "Prévente"
    Titres ="PV"
    Jour ="PV"
    Hdebut = "PV"
    Hfin = "PV"
    Duree = "PV"
    Langue = "PV"
    Catégorie = "PV"
    DSortie = "PV"
    Realisateurs = "PV"
    Acteurs ="PV"
    Synopsis = "PV"
    Avertissement = "RAS"
    NumSemaines = "0"
    Tag = "PV"
    
    return Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

def culte():    
    Type = "UGC Cultes"
    Titres ="Culte"
    Jour ="Culte"
    Hdebut = "Culte"
    Hfin = "Culte"
    Duree = "Culte"
    Langue = "Culte"
    Catégorie = "Culte"
    DSortie = "Culte"
    Realisateurs = "Culte"
    Acteurs ="Culte"
    Synopsis = "Culte"
    Avertissement = "RAS"
    NumSemaines = "RAS"
    Tag = "Culte"
    
    return Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

def ensalle():    
    Type = "En Salle"
    Titres ="ES"
    #Jour ="ES"
    Hdebut = "ES"
    Hfin = "ES"
    Duree = "ES"
    Langue = "ES"
    Catégorie = "ES"
    DSortie = "ES"
    Realisateurs = "ES"
    Acteurs ="ES"
    Synopsis = "ES"
    Avertissement = "RAS"
    NumSemaines = "RAS"
    Tag = "ES"
    
    return Type,Titres,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

# %%
a = True
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
time.sleep(2)
for key in cinemas.keys():
    print(key)
    driver.get(str(cinemas[key]))
    if(a):
        driver.find_element('xpath',"//*[@id=\"didomi-popup\"]/div/div/div/span").click()
        a = False
    
    #####################AVANTPREMIERES
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'lxml')
    try:

        avantpremières = soup.find_all('div',id='avantpremieres-donotmiss-tab')

        for film in avantpremières:
            infosfilms = film.find_all("div",class_="info-wrapper") 
            for info in infosfilms: 
                Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = avantPrem()
                date = info.find_all('li',class_="color--dark-blue")
                for d in date: 

                    titre = info.find('div',class_="block--title text-uppercase")
                    Titres = str(titre.text.strip())

                    realisateur = info.find('p',class_="p--medium color--dark-blue")
                    real = str(realisateur.text.strip())
                    Realisateurs = real[3:]

                    tempDate = str(d.find('a').text.strip())
                    Jour = tempDate[:-6]
                    Hdebut = tempDate[-5:]   
                    DSortie = tempDate[:-6]

                    synopsis = info.find('p',class_="p--medium color--dark-blue d-none d-md-block")
                    Synopsis = synopsis.text.strip()

                    listeCinemas.append(key)
                    listeType.append(Type)
                    listeTitres.append(Titres)
                    listeJour.append(Jour)
                    listeHdebut.append(Hdebut)
                    listeHfin.append(Hfin)
                    listeDuree.append(Duree)
                    listeLangue.append(Langue)
                    listeCatégorie.append(Catégorie)
                    listeDSortie.append(DSortie)
                    listeRealisateurs.append(Realisateurs)
                    listeActeurs.append(Acteurs)
                    listeSynopsis.append(Synopsis)
                    listeAvertissement.append(Avertissement)
                    listeNumSemaines.append(NumSemaines)
                    listeTag.append(Tag)
    except:
        print("Pas d'avant-premières")
        
    ###################PREVENTES
    try :    
        driver.execute_script("window.scrollTo(0, 200)") 
        driver.find_element('xpath',"//*[@id=\"preventes-tab\"]").click()
        time.sleep(2)

        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')

        preventes = soup.find_all('div',id="preventes-donotmiss-tab")

        for film in preventes:
            infosfilms = film.find_all("div",class_="info-wrapper") 
            Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = prev()
            for info in infosfilms: 
                titre = info.find('div',class_="block--title text-uppercase")
                Titres = str(titre.text.strip())

                realisateur = info.find('p',class_="p--medium color--dark-blue")
                real = realisateur.text.strip()
                Realisateurs = str(real[3:])

                synopsis = info.find('p',class_="p--medium color--dark-blue d-none d-md-block")
                Synopsis = synopsis.text.strip()

                listeCinemas.append(key)
                listeType.append(Type)
                listeTitres.append(Titres)
                listeJour.append(Jour)
                listeHdebut.append(Hdebut)
                listeHfin.append(Hfin)
                listeDuree.append(Duree)
                listeLangue.append(Langue)
                listeCatégorie.append(Catégorie)
                listeDSortie.append(DSortie)
                listeRealisateurs.append(Realisateurs)
                listeActeurs.append(Acteurs)
                listeSynopsis.append(Synopsis)
                listeAvertissement.append(Avertissement)
                listeNumSemaines.append(NumSemaines)
                listeTag.append(Tag)
    except : 
        print("Pas de préventes")
        
    ###############CULTES
    try:
    
        driver.find_element('xpath',"//*[@id=\"ugcculte-tab\"]").click()
        time.sleep(2)

        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')

        ugccultes = soup.find_all('div',id="ugcculte-donotmiss-tab") 

        for film in ugccultes:
            infosfilms = film.find_all("div",class_="info-wrapper") 
            Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = culte()
            for info in infosfilms: 
                date = info.find_all('li',class_="color--dark-blue")
                for d in date: 
                    titre = info.find('div',class_="block--title text-uppercase")
                    Titres = str(titre.text.strip())
                    
                    try:
                        realisateur = info.find('p',class_="p--medium color--dark-blue")
                        real = realisateur.text.strip()
                        Realisateurs = str(real[3:])
                    except:
                        Realisateurs = "Non renseigné"

                    tempDate = str(d.find('a').text.strip())
                    Jour = tempDate[:-6]
                    Hdebut = tempDate[-5:]   
                    DSortie = tempDate[:-6]

                    synopsis = info.find('p',class_="p--medium color--dark-blue d-none d-md-block")
                    Synopsis = synopsis.text.strip()

                    listeCinemas.append(key)
                    listeType.append(Type)
                    listeTitres.append(Titres)
                    listeJour.append(Jour)
                    listeHdebut.append(Hdebut)
                    listeHfin.append(Hfin)
                    listeDuree.append(Duree)
                    listeLangue.append(Langue)
                    listeCatégorie.append(Catégorie)
                    listeDSortie.append(DSortie)
                    listeRealisateurs.append(Realisateurs)
                    listeActeurs.append(Acteurs)
                    listeSynopsis.append(Synopsis)
                    listeAvertissement.append(Avertissement)
                    listeNumSemaines.append(NumSemaines)
                    listeTag.append(Tag)
    except : 
        print("Pas de films cultes")
        
    #####################EN SALLE
    avanceJours = 6 #Nombre de jours à regarder
    for countJours in range(1,avanceJours):   
        driver.find_element('xpath',f"//*[@id=\"nav-screening-list\"]/div[2]/div[1]/div/div/div/div/div/div[1]/div/div/div[{countJours}]").click()
        time.sleep(3)

        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')

        current = soup.find_all('div',class_="slick-slide slick-current slick-active")
        current = current[len(current)-1]
        for d in current:
            Jour = d.find('span',class_="text-uppercase").text.strip()

        allMovies = soup.find_all('div',class_="dates-content") #Toute la page des films
        for movie in allMovies:
            eachMovie = movie.find_all('div',class_="slider-item") #Chaque film tout seul

        for film in eachMovie:

            Type,Titres,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = ensalle()

            ########## PARTIE DE DROITE ##########

            infoHeure = film.find_all('li',class_="position-relative text-center")
            if(len(infoHeure)==0):
                prochaineSeance = film.find('p',class_="p--medium m-0 color--main-blue").text.strip()   
                tempJour = re.findall('\d.*',prochaineSeance)
                Jour = tempJour[0]
                Hdebut = "A definir"
                Hfin = "A definir"
                Langue = "A definir"

            else:
                seances = film.find_all('li',class_="position-relative text-center")
                for s in seances:
                    try:
                        Langue = s.find('span',class_="color--white text-uppercase screening-lang").text.strip()
                    except :
                        Langue = s.find('span',class_="color--light-blue text-uppercase screening-lang").text.strip()
                    Hdebut = s.find('div',class_="screening-start").text.strip()
                    tempHfin = s.find('div',class_="screening-end").text.strip()
                    Hfin = tempHfin[5:10]

                    ########## PARTIE DE GAUCHE ########## 

                    try:
                        NumSemaines = film.find('div',class_="nb-week text-uppercase color--main-blue").text.strip()
                    except:
                        NumSemaines = NumSemaines

                    Titres = film.find('div',class_="block--title text-uppercase").text.strip()


                    infoWrapper = film.find_all('div',class_="info-wrapper main") #Prendre seuelment les infos PC
                    for Info in infoWrapper:
                        groupInfo = Info.find_all('div',class_="group-info") #Infos du film

                        for groupinfo in groupInfo: #Pour chaque paragraphe d'infos         
                            if("Sortie le" in groupinfo.text):
                                DSortie = groupinfo.find('span',class_='color--dark-blue').text.strip()
                                categorie = groupinfo.find('p',class_="p--medium color--dark-blue d-none d-md-block").text.strip()
                                Duree = categorie[-5:-1]
                                Catégorie = categorie[:-7]
                            if(" De " in groupinfo.text):
                                groupGens = groupinfo.find_all('p',class_="p--medium color--grey d-none d-md-block")
                                for g in groupGens:
                                    if("De" in g.text):
                                        Realisateurs = g.find('span',class_='color--dark-blue').text.strip()
                                    if("Avec" in g.text):
                                        Acteurs = g.find('span',class_='color--dark-blue').text.strip()
                            if("Synopsis" in groupinfo.text):
                                Synopsis = groupinfo.find('span',class_="color--dark-blue").text.strip()
                            if("Avertissement" in groupinfo.text):
                                Avertissement = groupinfo.find('span',class_="color--dark-blue").text.strip()
                    listeCinemas.append(key)
                    listeType.append(Type)
                    listeTitres.append(Titres)
                    listeJour.append(Jour)
                    listeHdebut.append(Hdebut)
                    listeHfin.append(Hfin)
                    listeDuree.append(Duree)
                    listeLangue.append(Langue)
                    listeCatégorie.append(Catégorie)
                    listeDSortie.append(DSortie)
                    listeRealisateurs.append(Realisateurs)
                    listeActeurs.append(Acteurs)
                    listeSynopsis.append(Synopsis)
                    listeAvertissement.append(Avertissement)
                    listeNumSemaines.append(NumSemaines)
                    listeTag.append(Tag)

driver.quit()
# Out:
# <ipython-input-3-1b84e6fe5ec2>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# La Defense
# Pas de préventes
# Les Halles
# Montparnasse
# Pas de préventes
# Pas de films cultes

# %%
import pandas as pd


films = pd.DataFrame(list(zip(listeType,listeCinemas,listeTitres,listeJour,listeHdebut,
                              listeHfin,listeDuree, listeLangue,listeCatégorie,listeDSortie,
                              listeRealisateurs,listeActeurs,listeSynopsis,listeAvertissement,listeNumSemaines,listeTag)),
                     columns=['Type','Cinemas','Titre','Jour','Début','Fin','Durée','Langue','Catégories','Sortie','Realisateurs','Acteurs','Synopsis','Avertissement','NumSemaine','Tag'])
films
# Out:
#                  Type       Cinemas                       Titre  \
# 0     Avant-Premières    La Defense   ARRETE AVEC TES MENSONGES
# 1     Avant-Premières    La Defense               THE FABELMANS
# 2     Avant-Premières    La Defense  AINBO PRINCESSE D'AMAZONIE
# 3          UGC Cultes    La Defense    LA FIEVRE DU SAMEDI SOIR
# 4          UGC Cultes    La Defense               JURASSIC PARK
# ...               ...           ...                         ...
# 1373         En Salle  Montparnasse                 ALIBI.COM 2
# 1374         En Salle  Montparnasse                 ALIBI.COM 2
# 1375         En Salle  Montparnasse                 ALIBI.COM 2
# 1376         En Salle  Montparnasse           LES TETES GIVREES
# 1377         En Salle  Montparnasse           LES TETES GIVREES
#
#                  Jour  Début    Fin  Durée Langue          Catégories  \
# 0     20 février 2023  20:00     AP     AP     AP                  AP
# 1     19 février 2023  18:00     AP     AP     AP                  AP
# 2     19 février 2023  11:00     AP     AP     AP                  AP
# 3     19 février 2023  18:00  Culte  Culte  Culte               Culte
# 4     19 février 2023  11:00  Culte  Culte  Culte               Culte
# ...               ...    ...    ...    ...    ...                 ...
# 1373    Lun. 20 févr.  18:15  20:01   1h28     VF             Comédie
# 1374    Lun. 20 févr.  20:20  22:06   1h28     VF             Comédie
# 1375    Lun. 20 févr.  22:15  23:57   1h28     VF             Comédie
# 1376    Lun. 20 févr.  15:15  17:16   1h43     VF  Comédie Dramatique
# 1377    Lun. 20 févr.  19:55  21:56   1h43     VF  Comédie Dramatique
#
#                Sortie                Realisateurs  \
# 0     20 février 2023               Olivier Peyon
# 1     19 février 2023            Steven Spielberg
# 2     19 février 2023  Richard Claus, Jose Zelada
# 3     19 février 2023                 John Badham
# 4     19 février 2023               Non renseigné
# ...               ...                         ...
# 1373  08 février 2023            Philippe Lacheau
# 1374  08 février 2023            Philippe Lacheau
# 1375  08 février 2023            Philippe Lacheau
# 1376  08 février 2023              Stéphane Cazes
# 1377  08 février 2023              Stéphane Cazes
#
#                                                 Acteurs  \
# 0                                                    AP
# 1                                                    AP
# 2                                                    AP
# 3                                                 Culte
# 4                                                 Culte
# ...                                                 ...
# 1373     Philippe Lacheau, Élodie Fontan, Tarek Boudali
# 1374     Philippe Lacheau, Élodie Fontan, Tarek Boudali
# 1375     Philippe Lacheau, Élodie Fontan, Tarek Boudali
# 1376  Clovis Cornillac, Claudia Tagbo, Marwa Merdjet...
# 1377  Clovis Cornillac, Claudia Tagbo, Marwa Merdjet...
#
#                                                Synopsis Avertissement  \
# 0     Venez découvrir l'adaption du best-seller de P...           RAS
# 1     A l'issue de cette avant-première du nouveau f...           RAS
# 2     En famille, partez à l'aventure avec Ainbo, la...           RAS
# 3                   "Nice move. Did you make that up ?"           RAS
# 4                          "J'ai dépensé sans compter."           RAS
# ...                                                 ...           ...
# 1373  Après avoir fermé son agence Alibi.com et prom...           RAS
# 1374  Après avoir fermé son agence Alibi.com et prom...           RAS
# 1375  Après avoir fermé son agence Alibi.com et prom...           RAS
# 1376  Dans un collège au pied du Mont Blanc, les élè...           RAS
# 1377  Dans un collège au pied du Mont Blanc, les élè...           RAS
#
#      NumSemaine    Tag
# 0             0     AP
# 1             0     AP
# 2             0     AP
# 3           RAS  Culte
# 4           RAS  Culte
# ...         ...    ...
# 1373        RAS     ES
# 1374        RAS     ES
# 1375        RAS     ES
# 1376        RAS     ES
# 1377        RAS     ES
#
# [1378 rows x 16 columns]

# %%
filmsDefense = films[films['Cinemas']=='La Defense']
filmsHalles = films[films['Cinemas']=='Les Halles']

# %%
films[(films['Jour']=='Aujourd\'hui')&(films['Fin']<='19:30')&(films['Fin']>='19:00')].sort_values(by='Début',ascending=False)
# Out:
#           Type       Cinemas                                   Titre  \
# 25    En Salle    La Defense                                 MARLOWE
# 464   En Salle    Les Halles                        UN HOMME HEUREUX
# 63    En Salle    La Defense                             ALIBI.COM 2
# 492   En Salle    Les Halles  ASTERIX ET OBELIX : L'EMPIRE DU MILIEU
# 20    En Salle    La Defense                            L'ASTRONAUTE
# 1220  En Salle  Montparnasse                                 MARLOWE
# 560   En Salle    Les Halles                          RETOUR A SEOUL
# 11    En Salle    La Defense       ANT-MAN ET LA GUEPE : QUANTUMANIA
# 423   En Salle    Les Halles       ANT-MAN ET LA GUEPE : QUANTUMANIA
# 482   En Salle    Les Halles                        LA FAMILLE ASADA
#
#              Jour  Début    Fin Durée Langue  \
# 25    Aujourd'hui  17:20  19:27  1h49  VOSTF
# 464   Aujourd'hui  17:20  19:06  1h29     VF
# 63    Aujourd'hui  17:15  19:01  1h28     VF
# 492   Aujourd'hui  17:15  19:24  1h52     VF
# 20    Aujourd'hui  17:10  19:18  1h50     VF
# 1220  Aujourd'hui  17:10  19:17  1h49  VOSTF
# 560   Aujourd'hui  16:50  19:06  1h59  VOSTF
# 11    Aujourd'hui  16:45  19:07  2h04     VF
# 423   Aujourd'hui  16:40  19:02  2h04  VOSTF
# 482   Aujourd'hui  16:40  19:05  2h08  VOSTF
#
#                              Catégories           Sortie      Realisateurs  \
# 25                   Thriller, Policier  15 février 2023       Neil Jordan
# 464                             Comédie  15 février 2023   Tristan Séguéla
# 63                              Comédie  08 février 2023  Philippe Lacheau
# 492                   Comédie, Aventure  01 février 2023   Guillaume Canet
# 20                   Comédie Dramatique  15 février 2023    Nicolas Giraud
# 1220                 Thriller, Policier  15 février 2023       Neil Jordan
# 560                               Drame  25 janvier 2023         Davy Chou
# 11    Action, Science Fiction, Aventure  15 février 2023       Peyton Reed
# 423   Action, Science Fiction, Aventure  15 février 2023       Peyton Reed
# 482                             Comédie  25 janvier 2023      Ryôta Nakano
#
#                                                 Acteurs  \
# 25             Liam Neeson, Diane Kruger, Jessica Lange
# 464   Fabrice Luchini, Catherine Frot, Philippe Kate...
# 63       Philippe Lacheau, Élodie Fontan, Tarek Boudali
# 492   Guillaume Canet, Gilles Lellouche, Vincent Cassel
# 20    Nicolas Giraud, Mathieu Kassovitz, Hélène Vincent
# 1220           Liam Neeson, Diane Kruger, Jessica Lange
# 560            Park Ji-min (II), Oh Kwang-rok, Guka Han
# 11         Paul Rudd, Evangeline Lilly, Michael Douglas
# 423        Paul Rudd, Evangeline Lilly, Michael Douglas
# 482   Kazunari Ninomiya, Haru Kuroki, Satoshi Tsumabuki
#
#                                                Synopsis Avertissement  \
# 25    En 1939, à Bay City en Californie, alors que l...           RAS
# 464   Alors que Jean, maire très conservateur d'une ...           RAS
# 63    Après avoir fermé son agence Alibi.com et prom...           RAS
# 492   Nous sommes en 50 avant J.C. L’Impératrice de ...           RAS
# 20    Ingénieur en aéronautique chez ArianeGroup, Ji...           RAS
# 1220  En 1939, à Bay City en Californie, alors que l...           RAS
# 560   Sur un coup de tête, Freddie, 25 ans, retourne...           RAS
# 11    Les super-héros Ant-Man et la Guêpe vont explo...           RAS
# 423   Les super-héros Ant-Man et la Guêpe vont explo...           RAS
# 482   Dans la famille Asada, chacun a un rêve secret...           RAS
#
#      NumSemaine Tag
# 25      Nouveau  ES
# 464     Nouveau  ES
# 63          RAS  ES
# 492         RAS  ES
# 20      Nouveau  ES
# 1220    Nouveau  ES
# 560         RAS  ES
# 11      Nouveau  ES
# 423     Nouveau  ES
# 482         RAS  ES

# %%
films[films['Type']=='Avant-Premières']
# Out:
#                  Type       Cinemas                       Titre  \
# 0     Avant-Premières    La Defense   ARRETE AVEC TES MENSONGES
# 1     Avant-Premières    La Defense               THE FABELMANS
# 2     Avant-Premières    La Defense  AINBO PRINCESSE D'AMAZONIE
# 410   Avant-Premières    Les Halles               THE FABELMANS
# 411   Avant-Premières    Les Halles           A LA BELLE ETOILE
# 412   Avant-Premières    Les Halles                     PETITES
# 413   Avant-Premières    Les Halles                   CREED III
# 414   Avant-Premières    Les Halles                   CREED III
# 1213  Avant-Premières  Montparnasse                   CREED III
#
#                  Jour  Début Fin Durée Langue Catégories           Sortie  \
# 0     20 février 2023  20:00  AP    AP     AP         AP  20 février 2023
# 1     19 février 2023  18:00  AP    AP     AP         AP  19 février 2023
# 2     19 février 2023  11:00  AP    AP     AP         AP  19 février 2023
# 410   17 février 2023  21:00  AP    AP     AP         AP  17 février 2023
# 411   20 février 2023  20:15  AP    AP     AP         AP  20 février 2023
# 412   21 février 2023  20:15  AP    AP     AP         AP  21 février 2023
# 413   28 février 2023  19:30  AP    AP     AP         AP  28 février 2023
# 414   28 février 2023  22:00  AP    AP     AP         AP  28 février 2023
# 1213  28 février 2023  19:20  AP    AP     AP         AP  28 février 2023
#
#                     Realisateurs Acteurs  \
# 0                  Olivier Peyon      AP
# 1               Steven Spielberg      AP
# 2     Richard Claus, Jose Zelada      AP
# 410             Steven Spielberg      AP
# 411             Sébastien Tulard      AP
# 412          Julie Lerat-Gersant      AP
# 413            Michael B. Jordan      AP
# 414            Michael B. Jordan      AP
# 1213           Michael B. Jordan      AP
#
#                                                Synopsis Avertissement  \
# 0     Venez découvrir l'adaption du best-seller de P...           RAS
# 1     A l'issue de cette avant-première du nouveau f...           RAS
# 2     En famille, partez à l'aventure avec Ainbo, la...           RAS
# 410   Soirée hommage à Steven Spielberg : réservez v...           RAS
# 411     Réservez vos places sans frais dès maintenant !           RAS
# 412     Réservez vos places sans frais dès maintenant !           RAS
# 413     Réservez vos places sans frais dès maintenant !           RAS
# 414     Réservez vos places sans frais dès maintenant !           RAS
# 1213    Réservez vos places sans frais dès maintenant !           RAS
#
#      NumSemaine Tag
# 0             0  AP
# 1             0  AP
# 2             0  AP
# 410           0  AP
# 411           0  AP
# 412           0  AP
# 413           0  AP
# 414           0  AP
# 1213          0  AP
