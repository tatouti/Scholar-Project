# %%
#!pip install selenium
#!pip install lxml
#!pip install beautifulsoup4
#!pip install webdriver-manager
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re 
import requests

import time
from datetime import datetime

# %%
cinemas = {}
cinemas['La Defense'] = "https://www.ugc.fr/cinema.html?id=20"
cinemas['Les Halles'] = "https://www.ugc.fr/cinema.html?id=10"
cinemas['Montparnasse'] = "https://www.ugc.fr/cinema.html?id=14"

listeType =[]
listeCinemas =[]
listeTitres =[]
listeJour =[]
listeHdebut = []
listeHfin = []
listeDuree = []
listeLangue = []
listeCatégorie = []
listeDSortie = []
listeRealisateurs = []
listeActeurs =[]
listeSynopsis = []
listeAvertissement =[]
listeNumSemaines = []
listeTag =[]

def avantPrem():
    Type = "Avant-Premières"
    Titres ="AP"
    Jour ="AP"
    Hdebut = "AP"
    Hfin = "AP"
    Duree = "AP"
    Langue = "AP"
    Catégorie = "AP"
    DSortie = "AP"
    Realisateurs = "AP"
    Acteurs ="AP"
    Synopsis = "AP"
    Avertissement = "RAS"
    NumSemaines = "0"
    Tag = "AP"
    
    return Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

def prev():    
    Type = "Prévente"
    Titres ="PV"
    Jour ="PV"
    Hdebut = "PV"
    Hfin = "PV"
    Duree = "PV"
    Langue = "PV"
    Catégorie = "PV"
    DSortie = "PV"
    Realisateurs = "PV"
    Acteurs ="PV"
    Synopsis = "PV"
    Avertissement = "RAS"
    NumSemaines = "0"
    Tag = "PV"
    
    return Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

def culte():    
    Type = "UGC Cultes"
    Titres ="Culte"
    Jour ="Culte"
    Hdebut = "Culte"
    Hfin = "Culte"
    Duree = "Culte"
    Langue = "Culte"
    Catégorie = "Culte"
    DSortie = "Culte"
    Realisateurs = "Culte"
    Acteurs ="Culte"
    Synopsis = "Culte"
    Avertissement = "RAS"
    NumSemaines = "RAS"
    Tag = "Culte"
    
    return Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

def ensalle():    
    Type = "En Salle"
    Titres ="ES"
    #Jour ="ES"
    Hdebut = "ES"
    Hfin = "ES"
    Duree = "ES"
    Langue = "ES"
    Catégorie = "ES"
    DSortie = "ES"
    Realisateurs = "ES"
    Acteurs ="ES"
    Synopsis = "ES"
    Avertissement = "RAS"
    NumSemaines = "RAS"
    Tag = "ES"
    
    return Type,Titres,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag

# %%
a = True
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
time.sleep(1)
for key in cinemas.keys():
    print(key)
    driver.get(str(cinemas[key]))
    if(a):
        driver.find_element('xpath',"//*[@id=\"didomi-popup\"]/div/div/div/span").click()
        a = False
    
    #####################AVANTPREMIERES
    time.sleep(2)
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'lxml')
    try:

        avantpremières = soup.find_all('div',id='avantpremieres-donotmiss-tab')

        for film in avantpremières:
            infosfilms = film.find_all("div",class_="info-wrapper") 
            for info in infosfilms: 
                Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = avantPrem()
                date = info.find_all('li',class_="color--dark-blue")
                for d in date: 

                    titre = info.find('div',class_="block--title text-uppercase")
                    Titres = str(titre.text.strip())

                    realisateur = info.find('p',class_="p--medium color--dark-blue")
                    real = str(realisateur.text.strip())
                    Realisateurs = real[3:]

                    tempDate = str(d.find('a').text.strip())
                    Jour = tempDate[:-6]
                    Hdebut = tempDate[-5:]   
                    DSortie = tempDate[:-6]

                    synopsis = info.find('p',class_="p--medium color--dark-blue d-none d-md-block")
                    Synopsis = synopsis.text.strip()

                    listeCinemas.append(key)
                    listeType.append(Type)
                    listeTitres.append(Titres)
                    listeJour.append(Jour)
                    listeHdebut.append(Hdebut)
                    listeHfin.append(Hfin)
                    listeDuree.append(Duree)
                    listeLangue.append(Langue)
                    listeCatégorie.append(Catégorie)
                    listeDSortie.append(DSortie)
                    listeRealisateurs.append(Realisateurs)
                    listeActeurs.append(Acteurs)
                    listeSynopsis.append(Synopsis)
                    listeAvertissement.append(Avertissement)
                    listeNumSemaines.append(NumSemaines)
                    listeTag.append(Tag)
    except:
        print("Pas d'avant-premières")
        
    ###################PREVENTES
    try :    
        driver.execute_script("window.scrollTo(0, 200)") 
        driver.find_element('xpath',"//*[@id=\"preventes-tab\"]").click()
        time.sleep(2)

        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')

        preventes = soup.find_all('div',id="preventes-donotmiss-tab")

        for film in preventes:
            infosfilms = film.find_all("div",class_="info-wrapper") 
            Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = prev()
            for info in infosfilms: 
                titre = info.find('div',class_="block--title text-uppercase")
                Titres = str(titre.text.strip())

                realisateur = info.find('p',class_="p--medium color--dark-blue")
                real = realisateur.text.strip()
                Realisateurs = str(real[3:])

                synopsis = info.find('p',class_="p--medium color--dark-blue d-none d-md-block")
                Synopsis = synopsis.text.strip()

                listeCinemas.append(key)
                listeType.append(Type)
                listeTitres.append(Titres)
                listeJour.append(Jour)
                listeHdebut.append(Hdebut)
                listeHfin.append(Hfin)
                listeDuree.append(Duree)
                listeLangue.append(Langue)
                listeCatégorie.append(Catégorie)
                listeDSortie.append(DSortie)
                listeRealisateurs.append(Realisateurs)
                listeActeurs.append(Acteurs)
                listeSynopsis.append(Synopsis)
                listeAvertissement.append(Avertissement)
                listeNumSemaines.append(NumSemaines)
                listeTag.append(Tag)
    except : 
        print("Pas de préventes")
        
    ###############CULTES
    try:
    
        driver.find_element('xpath',"//*[@id=\"ugcculte-tab\"]").click()
        time.sleep(2)

        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')

        ugccultes = soup.find_all('div',id="ugcculte-donotmiss-tab") 

        for film in ugccultes:
            infosfilms = film.find_all("div",class_="info-wrapper") 
            Type,Titres,Jour,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = culte()
            for info in infosfilms: 
                date = info.find_all('li',class_="color--dark-blue")
                for d in date: 
                    titre = info.find('div',class_="block--title text-uppercase")
                    Titres = str(titre.text.strip())
                    
                    try:
                        realisateur = info.find('p',class_="p--medium color--dark-blue")
                        real = realisateur.text.strip()
                        Realisateurs = str(real[3:])
                    except:
                        Realisateurs = "Non renseigné"

                    tempDate = str(d.find('a').text.strip())
                    Jour = tempDate[:-6]
                    Hdebut = tempDate[-5:]   
                    DSortie = tempDate[:-6]

                    synopsis = info.find('p',class_="p--medium color--dark-blue d-none d-md-block")
                    Synopsis = synopsis.text.strip()

                    listeCinemas.append(key)
                    listeType.append(Type)
                    listeTitres.append(Titres)
                    listeJour.append(Jour)
                    listeHdebut.append(Hdebut)
                    listeHfin.append(Hfin)
                    listeDuree.append(Duree)
                    listeLangue.append(Langue)
                    listeCatégorie.append(Catégorie)
                    listeDSortie.append(DSortie)
                    listeRealisateurs.append(Realisateurs)
                    listeActeurs.append(Acteurs)
                    listeSynopsis.append(Synopsis)
                    listeAvertissement.append(Avertissement)
                    listeNumSemaines.append(NumSemaines)
                    listeTag.append(Tag)
    except : 
        print("Pas de films cultes")
        
    #####################EN SALLE
    avanceJours = 6 #Nombre de jours à regarder
    for countJours in range(1,avanceJours):   
        driver.find_element('xpath',f"//*[@id=\"nav-screening-list\"]/div[2]/div[1]/div/div/div/div/div/div[1]/div/div/div[{countJours}]").click()
        time.sleep(3)

        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')

        current = soup.find_all('div',class_="slick-slide slick-current slick-active")
        current = current[len(current)-1]
        for d in current:
            Jour = d.find('span',class_="text-uppercase").text.strip()

        allMovies = soup.find_all('div',class_="dates-content") #Toute la page des films
        for movie in allMovies:
            eachMovie = movie.find_all('div',class_="slider-item") #Chaque film tout seul

        for film in eachMovie:

            Type,Titres,Hdebut,Hfin,Duree,Langue,Catégorie,DSortie,Realisateurs,Acteurs,Synopsis,Avertissement,NumSemaines,Tag = ensalle()

            ########## PARTIE DE DROITE ##########

            infoHeure = film.find_all('li',class_="position-relative text-center")
            if(len(infoHeure)==0):
                prochaineSeance = film.find('p',class_="p--medium m-0 color--main-blue").text.strip()   
                tempJour = re.findall('\d.*',prochaineSeance)
                Jour = tempJour[0]
                Hdebut = "A definir"
                Hfin = "A definir"
                Langue = "A definir"

            else:
                seances = film.find_all('li',class_="position-relative text-center")
                for s in seances:
                    try:
                        Langue = s.find('span',class_="color--white text-uppercase screening-lang").text.strip()
                    except :
                        Langue = s.find('span',class_="color--light-blue text-uppercase screening-lang").text.strip()
                    Hdebut = s.find('div',class_="screening-start").text.strip()
                    tempHfin = s.find('div',class_="screening-end").text.strip()
                    Hfin = tempHfin[5:10]

                    ########## PARTIE DE GAUCHE ########## 

                    try:
                        NumSemaines = film.find('div',class_="nb-week text-uppercase color--main-blue").text.strip()
                    except:
                        NumSemaines = NumSemaines

                    Titres = film.find('div',class_="block--title text-uppercase").text.strip()


                    infoWrapper = film.find_all('div',class_="info-wrapper main") #Prendre seuelment les infos PC
                    for Info in infoWrapper:
                        groupInfo = Info.find_all('div',class_="group-info") #Infos du film

                        for groupinfo in groupInfo: #Pour chaque paragraphe d'infos         
                            if("Sortie le" in groupinfo.text):
                                DSortie = groupinfo.find('span',class_='color--dark-blue').text.strip()
                                categorie = groupinfo.find('p',class_="p--medium color--dark-blue d-none d-md-block").text.strip()
                                Duree = categorie[-5:-1]
                                Catégorie = categorie[:-7]
                            if(" De " in groupinfo.text):
                                groupGens = groupinfo.find_all('p',class_="p--medium color--grey d-none d-md-block")
                                for g in groupGens:
                                    if("De" in g.text):
                                        Realisateurs = g.find('span',class_='color--dark-blue').text.strip()
                                    if("Avec" in g.text):
                                        Acteurs = g.find('span',class_='color--dark-blue').text.strip()
                            if("Synopsis" in groupinfo.text):
                                Synopsis = groupinfo.find('span',class_="color--dark-blue").text.strip()
                            if("Avertissement" in groupinfo.text):
                                Avertissement = groupinfo.find('span',class_="color--dark-blue").text.strip()
                    listeCinemas.append(key)
                    listeType.append(Type)
                    listeTitres.append(Titres)
                    listeJour.append(Jour)
                    listeHdebut.append(Hdebut)
                    listeHfin.append(Hfin)
                    listeDuree.append(Duree)
                    listeLangue.append(Langue)
                    listeCatégorie.append(Catégorie)
                    listeDSortie.append(DSortie)
                    listeRealisateurs.append(Realisateurs)
                    listeActeurs.append(Acteurs)
                    listeSynopsis.append(Synopsis)
                    listeAvertissement.append(Avertissement)
                    listeNumSemaines.append(NumSemaines)
                    listeTag.append(Tag)

driver.quit()
# Out:
# <ipython-input-3-eeb9706b8982>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# La Defense
# Pas de préventes
# Les Halles
# Pas de films cultes
# Montparnasse
# Pas de films cultes

# %%
import pandas as pd


films = pd.DataFrame(list(zip(listeType,listeCinemas,listeTitres,listeJour,listeHdebut,
                              listeHfin,listeDuree, listeLangue,listeCatégorie,listeDSortie,
                              listeRealisateurs,listeActeurs,listeSynopsis,listeAvertissement,listeNumSemaines,listeTag)),
                     columns=['Type','Cinemas','Titre','Jour','Début','Fin','Durée','Langue','Catégories','Sortie','Realisateurs','Acteurs','Synopsis','Avertissement','NumSemaine','Tag'])
films
# Out:
#                  Type       Cinemas                      Titre  \
# 0     Avant-Premières    La Defense  ARRETE AVEC TES MENSONGES
# 1     Avant-Premières    La Defense              THE FABELMANS
# 2          UGC Cultes    La Defense   LA FIEVRE DU SAMEDI SOIR
# 3          UGC Cultes    La Defense              JURASSIC PARK
# 4          UGC Cultes    La Defense            CINEMA PARADISO
# ...               ...           ...                        ...
# 1236         En Salle  Montparnasse                ALIBI.COM 2
# 1237         En Salle  Montparnasse                ALIBI.COM 2
# 1238         En Salle  Montparnasse                ALIBI.COM 2
# 1239         En Salle  Montparnasse          LES TETES GIVREES
# 1240         En Salle  Montparnasse          LES TETES GIVREES
#
#                  Jour  Début    Fin  Durée Langue          Catégories  \
# 0     20 février 2023  20:00     AP     AP     AP                  AP
# 1     19 février 2023  18:00     AP     AP     AP                  AP
# 2     19 février 2023  18:00  Culte  Culte  Culte               Culte
# 3     19 février 2023  11:00  Culte  Culte  Culte               Culte
# 4     23 février 2023  20:00  Culte  Culte  Culte               Culte
# ...               ...    ...    ...    ...    ...                 ...
# 1236    Mar. 21 févr.  18:15  20:01   1h28     VF             Comédie
# 1237    Mar. 21 févr.  20:20  22:06   1h28     VF             Comédie
# 1238    Mar. 21 févr.  22:15  23:57   1h28     VF             Comédie
# 1239    Mar. 21 févr.  15:15  17:16   1h43     VF  Comédie Dramatique
# 1240    Mar. 21 févr.  19:55  21:56   1h43     VF  Comédie Dramatique
#
#                Sortie        Realisateurs  \
# 0     20 février 2023       Olivier Peyon
# 1     19 février 2023    Steven Spielberg
# 2     19 février 2023         John Badham
# 3     19 février 2023    Steven Spielberg
# 4     23 février 2023  Giuseppe Tornatore
# ...               ...                 ...
# 1236  08 février 2023    Philippe Lacheau
# 1237  08 février 2023    Philippe Lacheau
# 1238  08 février 2023    Philippe Lacheau
# 1239  08 février 2023      Stéphane Cazes
# 1240  08 février 2023      Stéphane Cazes
#
#                                                 Acteurs  \
# 0                                                    AP
# 1                                                    AP
# 2                                                 Culte
# 3                                                 Culte
# 4                                                 Culte
# ...                                                 ...
# 1236     Philippe Lacheau, Élodie Fontan, Tarek Boudali
# 1237     Philippe Lacheau, Élodie Fontan, Tarek Boudali
# 1238     Philippe Lacheau, Élodie Fontan, Tarek Boudali
# 1239  Clovis Cornillac, Claudia Tagbo, Marwa Merdjet...
# 1240  Clovis Cornillac, Claudia Tagbo, Marwa Merdjet...
#
#                                                Synopsis Avertissement  \
# 0     Venez découvrir l'adaption du best-seller de P...           RAS
# 1     A l'issue de cette avant-première du nouveau f...           RAS
# 2                   "Nice move. Did you make that up ?"           RAS
# 3                          "J'ai dépensé sans compter."           RAS
# 4     “Life isn't like in the movies. Life... is muc...           RAS
# ...                                                 ...           ...
# 1236  Après avoir fermé son agence Alibi.com et prom...           RAS
# 1237  Après avoir fermé son agence Alibi.com et prom...           RAS
# 1238  Après avoir fermé son agence Alibi.com et prom...           RAS
# 1239  Dans un collège au pied du Mont Blanc, les élè...           RAS
# 1240  Dans un collège au pied du Mont Blanc, les élè...           RAS
#
#      NumSemaine    Tag
# 0             0     AP
# 1             0     AP
# 2           RAS  Culte
# 3           RAS  Culte
# 4           RAS  Culte
# ...         ...    ...
# 1236        RAS     ES
# 1237        RAS     ES
# 1238        RAS     ES
# 1239        RAS     ES
# 1240        RAS     ES
#
# [1241 rows x 16 columns]

# %%
filmsDefense = films[films['Cinemas']=='La Defense']
filmsHalles = films[films['Cinemas']=='Les Halles']

# %%
films[(films['Jour']=='Aujourd\'hui')&(films['Fin']<='19:30')&(films['Fin']>='19:00')].sort_values(by='Début',ascending=False)
# Out:
# Empty DataFrame
# Columns: [Type, Cinemas, Titre, Jour, Début, Fin, Durée, Langue, Catégories, Sortie, Realisateurs, Acteurs, Synopsis, Avertissement, NumSemaine, Tag]
# Index: []

# %%
films[films['Type']=='Avant-Premières']
# Out:
#                  Type       Cinemas                      Titre  \
# 0     Avant-Premières    La Defense  ARRETE AVEC TES MENSONGES
# 1     Avant-Premières    La Defense              THE FABELMANS
# 387   Avant-Premières    Les Halles              THE FABELMANS
# 388   Avant-Premières    Les Halles          A LA BELLE ETOILE
# 389   Avant-Premières    Les Halles                    PETITES
# 390   Avant-Premières    Les Halles                  CREED III
# 391   Avant-Premières    Les Halles                  CREED III
# 1091  Avant-Premières  Montparnasse                  CREED III
#
#                  Jour  Début Fin Durée Langue Catégories           Sortie  \
# 0     20 février 2023  20:00  AP    AP     AP         AP  20 février 2023
# 1     19 février 2023  18:00  AP    AP     AP         AP  19 février 2023
# 387   17 février 2023  21:00  AP    AP     AP         AP  17 février 2023
# 388   20 février 2023  20:15  AP    AP     AP         AP  20 février 2023
# 389   21 février 2023  20:15  AP    AP     AP         AP  21 février 2023
# 390   28 février 2023  19:30  AP    AP     AP         AP  28 février 2023
# 391   28 février 2023  22:00  AP    AP     AP         AP  28 février 2023
# 1091  28 février 2023  19:20  AP    AP     AP         AP  28 février 2023
#
#              Realisateurs Acteurs  \
# 0           Olivier Peyon      AP
# 1        Steven Spielberg      AP
# 387      Steven Spielberg      AP
# 388      Sébastien Tulard      AP
# 389   Julie Lerat-Gersant      AP
# 390     Michael B. Jordan      AP
# 391     Michael B. Jordan      AP
# 1091    Michael B. Jordan      AP
#
#                                                Synopsis Avertissement  \
# 0     Venez découvrir l'adaption du best-seller de P...           RAS
# 1     A l'issue de cette avant-première du nouveau f...           RAS
# 387   Soirée hommage à Steven Spielberg : réservez v...           RAS
# 388     Réservez vos places sans frais dès maintenant !           RAS
# 389     Réservez vos places sans frais dès maintenant !           RAS
# 390     Réservez vos places sans frais dès maintenant !           RAS
# 391     Réservez vos places sans frais dès maintenant !           RAS
# 1091    Réservez vos places sans frais dès maintenant !           RAS
#
#      NumSemaine Tag
# 0             0  AP
# 1             0  AP
# 387           0  AP
# 388           0  AP
# 389           0  AP
# 390           0  AP
# 391           0  AP
# 1091          0  AP

# %%
films[films['Type']=='UGC Cultes']
# Out:
#          Type     Cinemas                     Titre             Jour  Début  \
# 2  UGC Cultes  La Defense  LA FIEVRE DU SAMEDI SOIR  19 février 2023  18:00
# 3  UGC Cultes  La Defense             JURASSIC PARK  19 février 2023  11:00
# 4  UGC Cultes  La Defense           CINEMA PARADISO  23 février 2023  20:00
# 5  UGC Cultes  La Defense               GRAN TORINO  26 février 2023  18:00
#
#      Fin  Durée Langue Catégories           Sortie        Realisateurs  \
# 2  Culte  Culte  Culte      Culte  19 février 2023         John Badham
# 3  Culte  Culte  Culte      Culte  19 février 2023    Steven Spielberg
# 4  Culte  Culte  Culte      Culte  23 février 2023  Giuseppe Tornatore
# 5  Culte  Culte  Culte      Culte  26 février 2023      Clint Eastwood
#
#   Acteurs                                           Synopsis Avertissement  \
# 2   Culte                "Nice move. Did you make that up ?"           RAS
# 3   Culte                       "J'ai dépensé sans compter."           RAS
# 4   Culte  “Life isn't like in the movies. Life... is muc...           RAS
# 5   Culte  "Il vous est jamais arrivé de tomber sur un me...           RAS
#
#   NumSemaine    Tag
# 2        RAS  Culte
# 3        RAS  Culte
# 4        RAS  Culte
# 5        RAS  Culte
